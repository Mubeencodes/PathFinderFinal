# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('architecture.csv')
df
# Out:
#     institute_id                                               name  \
# 0    IR-A-U-0573           Indian Institute of Technology Kharagpur
# 1    IR-A-U-0560             Indian Institute of Technology Roorkee
# 2    IR-A-U-0263           National Institute of Technology Calicut
# 3    IR-A-U-0127  Centre for Environmental Planning and Technolo...
# 4    IR-A-U-0116                School of Planning and Architecture
# 5    IR-A-U-0584  Indian Institute of Engineering Science and Te...
# 6    IR-A-U-0626                School of Planning and Architecture
# 7    IR-A-U-0467   National Institute of Technology Tiruchirappalli
# 8    IR-A-U-0627                School of Planning and Architecture
# 9    IR-A-U-0108                               Jamia Millia Islamia
# 10  IR-A-C-43708                  College of Engineering Trivandrum
# 11  IR-A-C-46330                Manipal Academy of Higher Education
# 12   IR-A-U-0202                      Birla Institute of Technology
# ...

# %%
# %%sql
